# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
complete_url = f"{url}q={filter_query}&sort={sort}&fl={field_list}&begin_date={begin_date}&end_date={end_date}"

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for check_pages in range(20):

    # create query with a page number
    # API results show 10 articles at a time
    query_url = (
    f"{url}api-key={nyt_api_key}&fq={filter_query}&fl={field_list}"
    + f"&begin_date={begin_date}&end_date={end_date}&sort={sort}")
    
    # Make a "GET" request and retrieve the JSON
    response = requests.get(query_url).json()

    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        for review in response["response"]["docs"]:
        # loop through the response["response"]["docs"] and append each review to the list
            reviews_list.append(review)
        # Print the page that was just retrieved
        print(f"Checked page {check_pages}")

        # Print the page number that had no results then break from the loop
    except:
        print(f"Failed on page {check_pages}")
        break
# Out:
# Checked page 0
# Checked page 1
# Checked page 2
# Checked page 3
# Checked page 4
# Checked page 5
# Checked page 6
# Checked page 7
# Checked page 8
# Checked page 9
# Checked page 10
# Checked page 11
# Checked page 12
# Checked page 13
# Checked page 14
# Checked page 15
# Checked page 16
# Checked page 17
# Checked page 18
# Checked page 19

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(reviews_list[:5], indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#         "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "What\u2019s Love Got to Do With It?",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kapur, Shekhar",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "James, Lily",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Azmi, Shabana",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Thompson, Emma",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T17:16:45+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 287
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#         "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "You Can Live Forever",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "You Can Live Forever (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Slutsky, Mark",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Watts, Sarah (Film Director)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "O'Driscoll, Anwen",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Laporte, June (Actor)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T11:00:08+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 294
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#         "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Tourist\u2019s  Guide to Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Tourist's Guide to Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Tsuchida, Steven",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cook, Rachael Leigh",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-21T07:03:25+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 276
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html",
#         "snippet": "A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone\u2019s lives.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#             "kicker": "Critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "Intoxicating Love With a Sobering Turn",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Zlotowski, Rebecca",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Other People's Children (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-20T15:35:13+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 801
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_list_df = pd.json_normalize(reviews_list)
reviews_list_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
reviews_list_df["title"] = reviews_list_df["headline.main"].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])
reviews_list_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
#                                            title
# 0                         The Attachment Diaries
# 1  What’s Love Got to Do With It?’ Probably a Lo
# 2                           You Can Live Forever
# 3                      A Tourist’s Guide to Love
# 4                        Other People’s Children

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_list_df["keywords"] = reviews_list_df["keywords"].apply(extract_keywords)
reviews_list_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;persons: Kapur, Shekhar;person...
# 2  subject: Movies;creative_works: You Can Live F...
# 3  subject: Movies;creative_works: A Tourist's Gu...
# 4  subject: Movies;persons: Zlotowski, Rebecca;cr...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
#                                            title
# 0                         The Attachment Diaries
# 1  What’s Love Got to Do With It?’ Probably a Lo
# 2                           You Can Live Forever
# 3                      A Tourist’s Guide to Love
# 4                        Other People’s Children

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles = (reviews_list_df["title"]).to_list()
titles
# Out:
# ['The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl']

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 1

# Loop through the titles
for title in titles:
    # Check if we need to sleep before making a request
        if request_counter % 50 == 0:
            time.sleep(1)

    # Add 1 to the request counter
        request_counter += 1

    # Perform a "GET" request for The Movie Database
        movie_reviews = requests.get(f"{url}{title}{tmdb_key_string}").json()

    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.
        try:
        # Get movie id
                movie_id = movie_reviews["results"][0]["id"]

        # Make a request for a the full movie details
                full_movie_details_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}"

        # Execute "GET" request with url
                full_movie_details_query = requests.get(full_movie_details_url).json()
        
        # Extract the genre names into a list
                genres = []
                for genre in full_movie_details_query["genres"]:
                    genres.append(genre["name"])

        # Extract the spoken_languages' English name into a list
                spoken_languages = []
                for language in full_movie_details_query["spoken_languages"]:
                    spoken_languages.append(language["english_name"])

        # Extract the production_countries' name into a list
                production_countries = []
                for country in full_movie_details_query["production_countries"]:
                    production_countries.append(country["name"])

        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
                combined_movie_data = {
                    "title" : full_movie_details_query["title"], 
                   "original_title" : full_movie_details_query["original_title"],
                   "budget" : full_movie_details_query["budget"] ,
                   "original_language" : full_movie_details_query["original_language"],
                   "homepage" : full_movie_details_query["homepage"], 
                   "overview" : full_movie_details_query["overview"], 
                   "popularity" : full_movie_details_query["popularity"], 
                   "runtime" : full_movie_details_query["runtime"], 
                   "revenue" : full_movie_details_query["revenue"], 
                   "release_date" : full_movie_details_query["release_date"], 
                   "vote_average" : full_movie_details_query["vote_average"], 
                   "vote_count" : full_movie_details_query["vote_count"],
                   "genres" : genres,
                   "spoken_languages" : spoken_languages,
                   "production_countries" : production_countries  
                }
                tmdb_movies_list.append(combined_movie_data)
        
        # Print out the title that was found
                print(f"{title} was found")

        except:
                print(f"{title} was not found")
# Out:
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found
# The Attachment Diaries was found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was found
# A Tourist’s Guide to Love was found
# Other People’s Children was found
# One True Loves was found
# The Lost Weekend: A Love Story was found
# A Thousand and One was found
# Your Place or Mine was found
# Love in the Time of Fentanyl was found

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(tmdb_movies_list[:5], indent=4))
# Out:
# [
#     {
#         "title": "The Attachment Diaries",
#         "original_title": "El apego",
#         "budget": 0,
#         "original_language": "es",
#         "homepage": "",
#         "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#         "popularity": 0.777,
#         "runtime": 102,
#         "revenue": 0,
#         "release_date": "2021-10-07",
#         "vote_average": 4.0,
#         "vote_count": 2,
#         "genres": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "spoken_languages": [
#             "Spanish"
#         ],
#         "production_countries": [
#             "Argentina"
#         ]
#     }
# ]

# %%
# Convert the results to a DataFrame
tmdb_df = pd.DataFrame(tmdb_movies_list)
tmdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 180 non-null    object
#  1   original_title        180 non-null    object
#  2   budget                180 non-null    int64
#  3   original_language     180 non-null    object
#  4   homepage              180 non-null    object
#  5   overview              180 non-null    object
#  6   popularity            180 non-null    float64
#  7   runtime               180 non-null    int64
#  8   revenue               180 non-null    int64
#  9   release_date          180 non-null    object
#  10  vote_average          180 non-null    float64
#  11  vote_count            180 non-null    int64
#  12  genres                180 non-null    object
#  13  spoken_languages      180 non-null    object
#  14  production_countries  180 non-null    object
# dtypes: float64(2), int64(4), object(9)
# memory usage: 21.2+ KB

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
merged_nyt_tmdb_df = pd.merge(reviews_list_df, tmdb_df, on= "title")
merged_nyt_tmdb_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/25/movies/the-...
# 2  https://www.nytimes.com/2023/05/25/movies/the-...
# 3  https://www.nytimes.com/2023/05/25/movies/the-...
# 4  https://www.nytimes.com/2023/05/25/movies/the-...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  A gynecologist and her patient form a horrifyi...  The New York Times
# 2  A gynecologist and her patient form a horrifyi...  The New York Times
# 3  A gynecologist and her patient form a horrifyi...  The New York Times
# 4  A gynecologist and her patient form a horrifyi...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;creative_works: The Attachment...
# 2  subject: Movies;creative_works: The Attachment...
# 3  subject: Movies;creative_works: The Attachment...
# 4  subject: Movies;creative_works: The Attachment...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-25T11:00:03+0000         295
# 2  2023-05-25T11:00:03+0000         295
# 3  2023-05-25T11:00:03+0000         295
# 4  2023-05-25T11:00:03+0000         295
#
#                                  headline.main headline.kicker  \
# 0  ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘The Attachment Diaries’ Review: Love, Sick            None
# 2  ‘The Attachment Diaries’ Review: Love, Sick            None
# 3  ‘The Attachment Diaries’ Review: Love, Sick            None
# 4  ‘The Attachment Diaries’ Review: Love, Sick            None
#
#   headline.content_kicker headline.print_headline  ...  \
# 0                    None  The Attachment Diaries  ...
# 1                    None  The Attachment Diaries  ...
# 2                    None  The Attachment Diaries  ...
# 3                    None  The Attachment Diaries  ...
# 4                    None  The Attachment Diaries  ...
#
#                                             overview popularity runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...      0.777     102
# 1  Argentina, 1970s. A desperate young woman goes...      0.777     102
# 2  Argentina, 1970s. A desperate young woman goes...      0.777     102
# 3  Argentina, 1970s. A desperate young woman goes...      0.777     102
# 4  Argentina, 1970s. A desperate young woman goes...      0.777     102
#
#   revenue release_date vote_average vote_count  \
# 0       0   2021-10-07          4.0          2
# 1       0   2021-10-07          4.0          2
# 2       0   2021-10-07          4.0          2
# 3       0   2021-10-07          4.0          2
# 4       0   2021-10-07          4.0          2
#
#                                genres  spoken_languages production_countries
# 0  [Drama, Mystery, Thriller, Horror]         [Spanish]          [Argentina]
# 1  [Drama, Mystery, Thriller, Horror]         [Spanish]          [Argentina]
# 2  [Drama, Mystery, Thriller, Horror]         [Spanish]          [Argentina]
# 3  [Drama, Mystery, Thriller, Horror]         [Spanish]          [Argentina]
# 4  [Drama, Mystery, Thriller, Horror]         [Spanish]          [Argentina]
#
# [5 rows x 31 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ["genres", "spoken_languages", "production_countries"]

# Create a list of characters to remove
characters_to_remove = ["[", "]", "'"]

# Loop through the list of columns to fix
for column in columns_to_fix:

    # Convert the column to type 'str'
    merged_nyt_tmdb_df[column] = merged_nyt_tmdb_df[column].astype(str) 

    # Loop through characters to remove
for char in characters_to_remove:
        merged_nyt_tmdb_df[column] = merged_nyt_tmdb_df[column].str.replace(char, '')

# Display the fixed DataFrame
merged_nyt_tmdb_df
# Out:
#                                                 web_url  \
# 0     https://www.nytimes.com/2023/05/25/movies/the-...
# 1     https://www.nytimes.com/2023/05/25/movies/the-...
# 2     https://www.nytimes.com/2023/05/25/movies/the-...
# 3     https://www.nytimes.com/2023/05/25/movies/the-...
# 4     https://www.nytimes.com/2023/05/25/movies/the-...
# ...                                                 ...
# 2795  https://www.nytimes.com/2023/02/02/movies/love...
# 2796  https://www.nytimes.com/2023/02/02/movies/love...
# 2797  https://www.nytimes.com/2023/02/02/movies/love...
# 2798  https://www.nytimes.com/2023/02/02/movies/love...
# 2799  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                 snippet              source  \
# 0     A gynecologist and her patient form a horrifyi...  The New York Times
# 1     A gynecologist and her patient form a horrifyi...  The New York Times
# 2     A gynecologist and her patient form a horrifyi...  The New York Times
# 3     A gynecologist and her patient form a horrifyi...  The New York Times
# 4     A gynecologist and her patient form a horrifyi...  The New York Times
# ...                                                 ...                 ...
# 2795  To combat the overdose crisis, a group that in...  The New York Times
# 2796  To combat the overdose crisis, a group that in...  The New York Times
# 2797  To combat the overdose crisis, a group that in...  The New York Times
# 2798  To combat the overdose crisis, a group that in...  The New York Times
# 2799  To combat the overdose crisis, a group that in...  The New York Times
#
#                                                keywords  \
# 0     subject: Movies;creative_works: The Attachment...
# 1     subject: Movies;creative_works: The Attachment...
# 2     subject: Movies;creative_works: The Attachment...
# 3     subject: Movies;creative_works: The Attachment...
# 4     subject: Movies;creative_works: The Attachment...
# ...                                                 ...
# 2795  subject: Documentary Films and Programs;subjec...
# 2796  subject: Documentary Films and Programs;subjec...
# 2797  subject: Documentary Films and Programs;subjec...
# 2798  subject: Documentary Films and Programs;subjec...
# 2799  subject: Documentary Films and Programs;subjec...
#
#                       pub_date  word_count  \
# 0     2023-05-25T11:00:03+0000         295
# 1     2023-05-25T11:00:03+0000         295
# 2     2023-05-25T11:00:03+0000         295
# 3     2023-05-25T11:00:03+0000         295
# 4     2023-05-25T11:00:03+0000         295
# ...                        ...         ...
# 2795  2023-02-02T12:00:11+0000         306
# 2796  2023-02-02T12:00:11+0000         306
# 2797  2023-02-02T12:00:11+0000         306
# 2798  2023-02-02T12:00:11+0000         306
# 2799  2023-02-02T12:00:11+0000         306
#
#                                           headline.main headline.kicker  \
# 0           ‘The Attachment Diaries’ Review: Love, Sick            None
# 1           ‘The Attachment Diaries’ Review: Love, Sick            None
# 2           ‘The Attachment Diaries’ Review: Love, Sick            None
# 3           ‘The Attachment Diaries’ Review: Love, Sick            None
# 4           ‘The Attachment Diaries’ Review: Love, Sick            None
# ...                                                 ...             ...
# 2795  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 2796  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 2797  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 2798  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 2799  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#      headline.content_kicker       headline.print_headline  ...  \
# 0                       None        The Attachment Diaries  ...
# 1                       None        The Attachment Diaries  ...
# 2                       None        The Attachment Diaries  ...
# 3                       None        The Attachment Diaries  ...
# 4                       None        The Attachment Diaries  ...
# ...                      ...                           ...  ...
# 2795                    None  Love in the Time Of Fentanyl  ...
# 2796                    None  Love in the Time Of Fentanyl  ...
# 2797                    None  Love in the Time Of Fentanyl  ...
# 2798                    None  Love in the Time Of Fentanyl  ...
# 2799                    None  Love in the Time Of Fentanyl  ...
#
#                                                overview popularity runtime  \
# 0     Argentina, 1970s. A desperate young woman goes...      0.777     102
# 1     Argentina, 1970s. A desperate young woman goes...      0.777     102
# 2     Argentina, 1970s. A desperate young woman goes...      0.777     102
# 3     Argentina, 1970s. A desperate young woman goes...      0.777     102
# 4     Argentina, 1970s. A desperate young woman goes...      0.777     102
# ...                                                 ...        ...     ...
# 2795  An intimate portrait of a community fighting t...      7.012      85
# 2796  An intimate portrait of a community fighting t...      7.012      85
# 2797  An intimate portrait of a community fighting t...      7.012      85
# 2798  An intimate portrait of a community fighting t...      7.012      85
# 2799  An intimate portrait of a community fighting t...      7.012      85
#
#      revenue release_date vote_average vote_count  \
# 0          0   2021-10-07          4.0          2
# 1          0   2021-10-07          4.0          2
# 2          0   2021-10-07          4.0          2
# 3          0   2021-10-07          4.0          2
# 4          0   2021-10-07          4.0          2
# ...      ...          ...          ...        ...
# 2795       0   2023-02-03          0.0          0
# 2796       0   2023-02-03          0.0          0
# 2797       0   2023-02-03          0.0          0
# 2798       0   2023-02-03          0.0          0
# 2799       0   2023-02-03          0.0          0
#
#                                           genres  spoken_languages  \
# 0     ['Drama', 'Mystery', 'Thriller', 'Horror']       ['Spanish']
# 1     ['Drama', 'Mystery', 'Thriller', 'Horror']       ['Spanish']
# 2     ['Drama', 'Mystery', 'Thriller', 'Horror']       ['Spanish']
# 3     ['Drama', 'Mystery', 'Thriller', 'Horror']       ['Spanish']
# 4     ['Drama', 'Mystery', 'Thriller', 'Horror']       ['Spanish']
# ...                                          ...               ...
# 2795                             ['Documentary']       ['English']
# 2796                             ['Documentary']       ['English']
# 2797                             ['Documentary']       ['English']
# 2798                             ['Documentary']       ['English']
# 2799                             ['Documentary']       ['English']
#
#                   production_countries
# 0                            Argentina
# 1                            Argentina
# 2                            Argentina
# 3                            Argentina
# 4                            Argentina
# ...                                ...
# 2795  Canada, United States of America
# 2796  Canada, United States of America
# 2797  Canada, United States of America
# 2798  Canada, United States of America
# 2799  Canada, United States of America
#
# [2800 rows x 31 columns]

# %%
# Drop "byline.person" column
dropped_byline_data = merged_nyt_tmdb_df.drop(["byline.person"], axis=1)
dropped_byline_data
# Out:
#                                                 web_url  \
# 0     https://www.nytimes.com/2023/05/25/movies/the-...
# 1     https://www.nytimes.com/2023/05/25/movies/the-...
# 2     https://www.nytimes.com/2023/05/25/movies/the-...
# 3     https://www.nytimes.com/2023/05/25/movies/the-...
# 4     https://www.nytimes.com/2023/05/25/movies/the-...
# ...                                                 ...
# 2795  https://www.nytimes.com/2023/02/02/movies/love...
# 2796  https://www.nytimes.com/2023/02/02/movies/love...
# 2797  https://www.nytimes.com/2023/02/02/movies/love...
# 2798  https://www.nytimes.com/2023/02/02/movies/love...
# 2799  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                 snippet              source  \
# 0     A gynecologist and her patient form a horrifyi...  The New York Times
# 1     A gynecologist and her patient form a horrifyi...  The New York Times
# 2     A gynecologist and her patient form a horrifyi...  The New York Times
# 3     A gynecologist and her patient form a horrifyi...  The New York Times
# 4     A gynecologist and her patient form a horrifyi...  The New York Times
# ...                                                 ...                 ...
# 2795  To combat the overdose crisis, a group that in...  The New York Times
# 2796  To combat the overdose crisis, a group that in...  The New York Times
# 2797  To combat the overdose crisis, a group that in...  The New York Times
# 2798  To combat the overdose crisis, a group that in...  The New York Times
# 2799  To combat the overdose crisis, a group that in...  The New York Times
#
#                                                keywords  \
# 0     subject: Movies;creative_works: The Attachment...
# 1     subject: Movies;creative_works: The Attachment...
# 2     subject: Movies;creative_works: The Attachment...
# 3     subject: Movies;creative_works: The Attachment...
# 4     subject: Movies;creative_works: The Attachment...
# ...                                                 ...
# 2795  subject: Documentary Films and Programs;subjec...
# 2796  subject: Documentary Films and Programs;subjec...
# 2797  subject: Documentary Films and Programs;subjec...
# 2798  subject: Documentary Films and Programs;subjec...
# 2799  subject: Documentary Films and Programs;subjec...
#
#                       pub_date  word_count  \
# 0     2023-05-25T11:00:03+0000         295
# 1     2023-05-25T11:00:03+0000         295
# 2     2023-05-25T11:00:03+0000         295
# 3     2023-05-25T11:00:03+0000         295
# 4     2023-05-25T11:00:03+0000         295
# ...                        ...         ...
# 2795  2023-02-02T12:00:11+0000         306
# 2796  2023-02-02T12:00:11+0000         306
# 2797  2023-02-02T12:00:11+0000         306
# 2798  2023-02-02T12:00:11+0000         306
# 2799  2023-02-02T12:00:11+0000         306
#
#                                           headline.main headline.kicker  \
# 0           ‘The Attachment Diaries’ Review: Love, Sick            None
# 1           ‘The Attachment Diaries’ Review: Love, Sick            None
# 2           ‘The Attachment Diaries’ Review: Love, Sick            None
# 3           ‘The Attachment Diaries’ Review: Love, Sick            None
# 4           ‘The Attachment Diaries’ Review: Love, Sick            None
# ...                                                 ...             ...
# 2795  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 2796  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 2797  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 2798  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 2799  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#      headline.content_kicker       headline.print_headline  ...  \
# 0                       None        The Attachment Diaries  ...
# 1                       None        The Attachment Diaries  ...
# 2                       None        The Attachment Diaries  ...
# 3                       None        The Attachment Diaries  ...
# 4                       None        The Attachment Diaries  ...
# ...                      ...                           ...  ...
# 2795                    None  Love in the Time Of Fentanyl  ...
# 2796                    None  Love in the Time Of Fentanyl  ...
# 2797                    None  Love in the Time Of Fentanyl  ...
# 2798                    None  Love in the Time Of Fentanyl  ...
# 2799                    None  Love in the Time Of Fentanyl  ...
#
#                                                overview popularity runtime  \
# 0     Argentina, 1970s. A desperate young woman goes...      0.777     102
# 1     Argentina, 1970s. A desperate young woman goes...      0.777     102
# 2     Argentina, 1970s. A desperate young woman goes...      0.777     102
# 3     Argentina, 1970s. A desperate young woman goes...      0.777     102
# 4     Argentina, 1970s. A desperate young woman goes...      0.777     102
# ...                                                 ...        ...     ...
# 2795  An intimate portrait of a community fighting t...      7.012      85
# 2796  An intimate portrait of a community fighting t...      7.012      85
# 2797  An intimate portrait of a community fighting t...      7.012      85
# 2798  An intimate portrait of a community fighting t...      7.012      85
# 2799  An intimate portrait of a community fighting t...      7.012      85
#
#      revenue release_date vote_average vote_count  \
# 0          0   2021-10-07          4.0          2
# 1          0   2021-10-07          4.0          2
# 2          0   2021-10-07          4.0          2
# 3          0   2021-10-07          4.0          2
# 4          0   2021-10-07          4.0          2
# ...      ...          ...          ...        ...
# 2795       0   2023-02-03          0.0          0
# 2796       0   2023-02-03          0.0          0
# 2797       0   2023-02-03          0.0          0
# 2798       0   2023-02-03          0.0          0
# 2799       0   2023-02-03          0.0          0
#
#                                           genres spoken_languages  \
# 0     ['Drama', 'Mystery', 'Thriller', 'Horror']      ['Spanish']
# 1     ['Drama', 'Mystery', 'Thriller', 'Horror']      ['Spanish']
# 2     ['Drama', 'Mystery', 'Thriller', 'Horror']      ['Spanish']
# 3     ['Drama', 'Mystery', 'Thriller', 'Horror']      ['Spanish']
# 4     ['Drama', 'Mystery', 'Thriller', 'Horror']      ['Spanish']
# ...                                          ...              ...
# 2795                             ['Documentary']      ['English']
# 2796                             ['Documentary']      ['English']
# 2797                             ['Documentary']      ['English']
# 2798                             ['Documentary']      ['English']
# 2799                             ['Documentary']      ['English']
#
#                   production_countries
# 0                            Argentina
# 1                            Argentina
# 2                            Argentina
# 3                            Argentina
# 4                            Argentina
# ...                                ...
# 2795  Canada, United States of America
# 2796  Canada, United States of America
# 2797  Canada, United States of America
# 2798  Canada, United States of America
# 2799  Canada, United States of America
#
# [2800 rows x 30 columns]

# %%
# Delete duplicate rows and reset index
updated_merged_data = merged_nyt_tmdb_df.drop_duplicates().reset_index(drop=True)
updated_merged_data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/artemis/Library/Mobile Documents/com~apple~CloudDocs/Coding/AI Bootcamp/DataClass/data-sourcing-challenge/retrieve_movie_data.ipynb Cell 22 line 2
#       <a href='vscode-notebook-cell:/Users/artemis/Library/Mobile%20Documents/com~apple~CloudDocs/Coding/AI%20Bootcamp/DataClass/data-sourcing-challenge/retrieve_movie_data.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> # Delete duplicate rows and reset index
# ----> <a href='vscode-notebook-cell:/Users/artemis/Library/Mobile%20Documents/com~apple~CloudDocs/Coding/AI%20Bootcamp/DataClass/data-sourcing-challenge/retrieve_movie_data.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> updated_merged_data = merged_nyt_tmdb_df.drop_duplicates().reset_index(drop=True)
#       <a href='vscode-notebook-cell:/Users/artemis/Library/Mobile%20Documents/com~apple~CloudDocs/Coding/AI%20Bootcamp/DataClass/data-sourcing-challenge/retrieve_movie_data.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a> updated_merged_data.head()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:6522, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6519 inplace = validate_bool_kwarg(inplace, "inplace")
#    6520 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6522 result = self[-self.duplicated(subset, keep=keep)]
#    6523 if ignore_index:
#    6524     result.index = default_index(len(result))
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:6662, in DataFrame.duplicated(self, subset, keep)
#    6660 else:
#    6661     vals = (col.values for name, col in self.items() if name in subset)
# -> 6662     labels, shape = map(list, zip(*map(f, vals)))
#    6664     ids = get_group_index(
#    6665         labels,
#    6666         # error: Argument 1 to "tuple" has incompatible type "List[_T]";
#    (...)
#    6670         xnull=False,
#    6671     )
#    6672     result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:6630, in DataFrame.duplicated.<locals>.f(vals)
#    6629 def f(vals) -> tuple[np.ndarray, int]:
# -> 6630     labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6631     return labels.astype("i8", copy=False), len(shape)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:780, in factorize(values, sort, use_na_sentinel, size_hint)
#     777             # Don't modify (potentially user-provided) array
#     778             values = np.where(null_mask, na_value, values)
# --> 780     codes, uniques = factorize_array(
#     781         values,
#     782         use_na_sentinel=use_na_sentinel,
#     783         size_hint=size_hint,
#     784     )
#     786 if sort and len(uniques) > 0:
#     787     uniques, codes = safe_sort(
#     788         uniques,
#     789         codes,
#    (...)
#     792         verify=False,
#     793     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:581, in factorize_array(values, use_na_sentinel, size_hint, na_value, mask)
#     578 hash_klass, values = _get_hashtable_algo(values)
#     580 table = hash_klass(size_hint or len(values))
# --> 581 uniques, codes = table.factorize(
#     582     values,
#     583     na_sentinel=-1,
#     584     na_value=na_value,
#     585     mask=mask,
#     586     ignore_na=use_na_sentinel,
#     587 )
#     589 # re-cast e.g. i8->dt64/td64, uint8->bool
#     590 uniques = _reconstruct_data(uniques, original.dtype, original)
#
# File pandas/_libs/hashtable_class_helper.pxi:7280, in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# File pandas/_libs/hashtable_class_helper.pxi:7194, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
# Export data to CSV without the index
updated_merged_data.to_csv("merged_nyt_tmdb_df.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/artemis/Library/Mobile Documents/com~apple~CloudDocs/Coding/AI Bootcamp/DataClass/data-sourcing-challenge/retrieve_movie_data.ipynb Cell 23 line 2
#       <a href='vscode-notebook-cell:/Users/artemis/Library/Mobile%20Documents/com~apple~CloudDocs/Coding/AI%20Bootcamp/DataClass/data-sourcing-challenge/retrieve_movie_data.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> # Export data to CSV without the index
# ----> <a href='vscode-notebook-cell:/Users/artemis/Library/Mobile%20Documents/com~apple~CloudDocs/Coding/AI%20Bootcamp/DataClass/data-sourcing-challenge/retrieve_movie_data.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> updated_merged_data.to_csv("merged_nyt_tmdb_df.csv", index=False)
#
# NameError: name 'updated_merged_data' is not defined
